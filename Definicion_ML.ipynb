# %% [markdown]
# ![imagen](./img/ejercicios.png)

# %% [markdown]
# # INFORMACIÓN DEL PROYECTO

# %% [markdown]
# ### TÍTULO

# %%
#Escribe el título del proyecto en Markdown
titulo = "Cómo hacerse rico con cartón"

# %% [markdown]
# ### TEMA

# %%
# Describe brevemente el tema del proyecto en Markdown
tema = "Predicción de precios de una carta de Magic mediante Machine Learning"

# %% [markdown]
# ### OBJETIVOS

# %% [markdown]
# Define aquí el objetivo del proyecto

# %% [markdown]
# * Predecir el precio de una carta revelada, pero no publicada.
# * Predecir el precio de una carta inventada para comprender su impacto en el mercado de cartas antes de su publicación.
# * Comprender qué atributos se consideran de mayor peso a la hora de establecer un precio mediante la Ciencia de Datos.
#
# ¿Utilidades prácticas?
# El juego del mercado de valores: Una carta recién publicada con un precio bajo en el mercado, pero uno alto predecido
# podría ser un buen objetivo de inversión a futuro. Ya que es posible que en su salida aún no se haya descubierto su valor real.

# %% [markdown]
# ## OBTENCIÓN DE LOS DATOS

# %% [markdown]
# ### DATASETS Y FUENTES ALTERNATIVAS DE DATOS

# %% [markdown]
# Incluye aquí una vista del dataset o datasets de los que partirás para poder evaluar tu hipótesis. <br>
# También incluye el origen de estos datos y su fuente.

# %%
import pandas as pd

# %% [markdown]
# Muestra mediante un head() los principales datasets con los que vas a trabajar

# %%
# Primer dataset
df_1 = pd.read_csv("src/data/dataCards.csv")

# %%
df_1
# Out:
#                       name released_at  layout     mana_cost  cmc  \
# 0                   Forest  2024-08-02  normal           NaN  0.0
# 1              Fury Sliver  2006-10-06  normal        {5}{R}  6.0
# 2            Kor Outfitter  2009-10-02  normal        {W}{W}  2.0
# 3                   Spirit  2015-05-22   token           NaN  0.0
# 4            Siren Lookout  2017-09-29  normal        {2}{U}  3.0
# ...                    ...         ...     ...           ...  ...
# 96734  Aggressive Biomancy  2024-06-14  normal  {X}{X}{G}{U}  2.0
# 96735         Horned Troll  2003-07-28  normal        {2}{G}  3.0
# 96736  Faerie Bladecrafter  2023-09-08  normal        {2}{B}  3.0
# 96737  Exultant Skymarcher  2018-01-19  normal     {1}{W}{W}  3.0
# 96738         Disintegrate  2022-11-28  normal        {X}{R}  1.0
#
#                         type_line  \
# 0             Basic Land — Forest
# 1               Creature — Sliver
# 2          Creature — Kor Soldier
# ...
